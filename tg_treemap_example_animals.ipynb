# %%
import pandas as pd
import random
import tg_treemap

# %%
tg_treemap.__version__
# Out:
# '0.2'

# %%
data = {
    "h1": ["Vertebrates", "Vertebrates", "Vertebrates", "Vertebrates", "Vertebrates", 
                 "Vertebrates", "Vertebrates", "Vertebrates", "Vertebrates", "Vertebrates", 
                 "Vertebrates", "Vertebrates", "Vertebrates", "Vertebrates", "Vertebrates", 
                 "Invertebrates", "Invertebrates", "Invertebrates", "Invertebrates", "Invertebrates", 
                 "Invertebrates", "Invertebrates", "Invertebrates", "Invertebrates"],
    "h2": ["Warm-Blooded Mammals", "Warm-Blooded Mammals", "Warm-Blooded Mammals", 
                    "Warm-Blooded Birds", "Warm-Blooded Birds", "Warm-Blooded Birds", 
                    "Cold-Blooded Fish", "Cold-Blooded Fish", "Cold-Blooded Fish", 
                    "Cold-Blooded Reptiles", "Cold-Blooded Reptiles", "Cold-Blooded Reptiles", 
                    "Cold-Blooded Amphibians", "Cold-Blooded Amphibians", "Cold-Blooded Amphibians", 
                    "3 Leg Pairs", "3 Leg Pairs", "3 Leg Pairs", 
                    "More than 3 Leg Pairs", "More than 3 Leg Pairs", "More than 3 Leg Pairs", 
                    "Worm-like", "Worm-like", "Not-worm-like"],
    "h3": ["Bear", "Tiger", "Whale", "Ostrich", "Peacock", "Eagle", 
               "Salmon", "Goldfish", "Shark", "Turtle", "Crocodile", "Snake", 
               "Axolotl", "Frog", "Salamander", "Ant", "Cockroach", "Ladybug", 
               "Scorpion", "Spider", "Millipede", "Earthworm", "Leech", "Tapeworm"]
}


df = pd.DataFrame(data)
random.seed(4711)
df = pd.concat([df, 
                pd.DataFrame([random.randint(5,30) for item in range(0,df.shape[0])], columns=['value'])
                ], axis=1)
df['idx'] = (df.index).astype(str).str.zfill(2)

# %%
override = {
    "Leech": {
        "fillcolor": "green",
        "fontcolor": "white",
        "fontsize": 12,
    },
    "Salamander": {
        "fillcolor": "blue",
        "fontsize": 12,
        "fontfamily": "Times New Roman"
    }
}



p,layer3 =tg_treemap.tg_treemap(df,#.drop('h3', axis=1), 
           width=1600,
           height=1200,
           h1_pad=35,
           h2_pad=0,
           pads=[1,2,1],
           fillcolumn='h2',
           fontcolors=['black','darkblue','black'],
           fontfamily='Arial', 
           fontsizes=[12,10,10],
           includeNumbers=['no','no','yes'],
           fillcolors=['#AEC6CF','#FFB7B2','#C1E1C1','#FFDAC1','#FFDAC1','#E2F0CB','tomato', 'lightblue', 'lightgray'],
           labeltype=['label','text','label'],
           l2_mul_horizontally=10,
           l3_mul_horizontally=15.2,
           linecolors=['black','darkblue'],
           override=override,
           canvascolor='white',
           backgroundcolor='white')
override = pd.DataFrame(override).T.reset_index().rename(columns={'index':'h3'})

p

# %% [markdown]
# 00 <a target="_blank" href="https://icons8.com/icon/Z5EtJ0Xu2LlI/bear">Bear</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 01 <a target="_blank" href="https://icons8.com/icon/AJFZJZNezGuE/year-of-tiger">Tiger</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a> <br>
# 02 <a target="_blank" href="https://icons8.com/icon/95633/whale">Whale</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 03 <a target="_blank" href="https://icons8.com/icon/lL9VCl82Lh9i/ostrich">Ostrich</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a> <br>
# 04 <a target="_blank" href="https://icons8.com/icon/wsgoBAMHEGd8/peacock">Peacock</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a> <br>
# 05 <a target="_blank" href="https://icons8.com/icon/3yeuRwmmMKej/eagle">Eagle</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 06 <a target="_blank" href="https://icons8.com/icon/04Un8Sly9qwb/salmon">salmon</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 07 <a target="_blank" href="https://icons8.com/icon/y4XDzw5bwn4p/tetra-goldfish">Tetra Goldfish</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 08 <a target="_blank" href="https://icons8.com/icon/Ea84372bHGU0/shark">Shark</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 09 <a target="_blank" href="https://icons8.com/icon/101755/turtle">Turtle</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 10 <a target="_blank" href="https://icons8.com/icon/IfSLM4GSKysT/crocodile">Crocodile</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 11 <a target="_blank" href="https://icons8.com/icon/qQWxL5FgeL3L/rattlesnake">Snake</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 13 <a target="_blank" href="https://icons8.com/icon/95560/frog">toad</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 14 <a target="_blank" href="https://icons8.com/icon/95597/salamander">Salamander</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 15 <a target="_blank" href="https://icons8.com/icon/95484/ant">Ant</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 16 <a target="_blank" href="https://icons8.com/icon/95505/cockroach">Cockroach</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 17 <a target="_blank" href="https://icons8.com/icon/95533/ladybug">Ladybug</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 18 <a target="_blank" href="https://icons8.com/icon/V8hXwHNHWMj8/scorp">Scorpion</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 19 <a target="_blank" href="https://icons8.com/icon/95618/spider">Spider</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>
# 21 <a target="_blank" href="https://icons8.com/icon/95546/earthworm">Earthworm</a> icon by <a target="_blank" href="https://icons8.com">Icons8</a><br>

# %% [markdown]
# # Add images

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
images = os.listdir('./images')
layer3['image'] =  layer3['idx']+'-' + layer3['h3'].str.lower() + 'x.gif'
layer3['image'] = np.where(layer3['image'].isin(images),layer3['image'],None)

# %%
fig = p.draw()
ax = fig.axes[0]

l3 = layer3.copy().dropna(subset='image')
for i, row in l3.iterrows():
    img = matplotlib.offsetbox.OffsetImage(
        plt.imread('./images/' + row['image']), 
        zoom = .5)
    ax.add_artist(matplotlib.offsetbox.AnnotationBbox(img,
        (row['x']+row['dx']/2 ,row['y']+row['dy']/2-30)
        ,pad = 0.0
        ,frameon =False
        ,zorder=20
        )
        )
fig
